# %%
#Ishaan
from ultralytics import YOLO
from pathlib import Path

    
synthetic_dataset = Path("shape_dataset")
model = YOLO("yolo11n.pt")
results = model.train(data = "/Users/Rai/Downloads/Classifying-malignancy-in-lung-nodules-using-deep-learning-models/shape_dataset/dataset.yaml",
                      epochs = 50, imgsz = 640, batch = 16
)
print(results.save_dir)
# Out:
# New https://pypi.org/project/ultralytics/8.4.161 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.157 🚀 Python-3.11.14 torch-2.14.0 CPU (Apple M2)
# ...

# %%
x = [1,2,3]
print(x[0:0])
# Out:
# []

# %%
#Ishaan
from ultralytics import YOLO

# Load your newly trained custom model
model = YOLO("runs/detect/train/weights/best.pt")

# Predict on a new image
results = model.predict(source="/Users/Rai/Downloads/Classifying-malignancy-in-lung-nodules-using-deep-learning-models/shape_dataset/images/train", save=True)
# Out:
# image 1/700 /Users/Rai/Downloads/Classifying-malignancy-in-lung-nodules-using-deep-learning-models/shape_dataset/images/train/img_00001.jpg: 640x640 1 rectangle, 1 triangle, 97.9ms
# image 2/700 /Users/Rai/Downloads/Classifying-malignancy-in-lung-nodules-using-deep-learning-models/shape_dataset/images/train/img_00002.jpg: 640x640 1 rectangle, 2 circles, 47.5ms
# image 3/700 /Users/Rai/Downloads/Classifying-malignancy-in-lung-nodules-using-deep-learning-models/shape_dataset/images/train/img_00004.jpg: 640x640 1 rectangle, 2 triangles, 1 circle, 45.8ms
# image 4/700 /Users/Rai/Downloads/Classifying-malignancy-in-lung-nodules-using-deep-learning-models/shape_dataset/images/train/img_00005.jpg: 640x640 3 rectangles, 2 triangles, 45.0ms
# image 5/700 /Users/Rai/Downloads/Classifying-malignancy-in-lung-nodules-using-deep-learning-models/shape_dataset/images/train/img_00008.jpg: 640x640 1 rectangle, 3 triangles, 45.2ms
# ...

# %%
# %pip install ultralytics
# Out:
# ...
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached opencv_python-5.0.0.93-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# ...
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached torch-2.14.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (38 kB)
# ...
#   Using cached torchvision-0.29.0-cp311-cp311-macosx_14_0_arm64.whl.metadata (5.7 kB)
# ...
#   Using cached polars-1.44.2-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached nvidia_ml_py-13.610.43-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached ultralytics_thop-2.1.6-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached polars_runtime_32-1.44.2-cp310-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# ...
#   Using cached charset_normalizer-3.5.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (45 kB)
# ...
#   Using cached urllib3-2.8.0-py3-none-any.whl.metadata (7.4 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# ...

# %%
# Out:
#   Cell In[2], line 1
#     yolo checks
#          ^
# SyntaxError: invalid syntax
